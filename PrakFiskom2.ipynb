# %% [markdown]
# # Bagian 1 : Tutorial Sintaks Python

# %%
#cara menampilkan hasil
m = 10
print(m)
print("hasil m+m = ", m+m)
print("hasil m x m = ", m*m)
# Out:
# 10
# hasil m+m =  20
# hasil m x m =  100

# %%
#menampilkan karakter
kar_1 = 'AKU KUAT'
kar_2 = 'AKU HEBAT'
kar_3 = 'HARUS SEMANGATTTT'
print(kar_1+' '+kar_2+' '+kar_3)
print(kar_1[2:10])
karakter = 'AKU KUAT AKU HEBAT AKU SEMANGATTTT'
print(karakter.split())
# Out:
# AKU KUAT AKU HEBAT HARUS SEMANGATTTT
# U KUAT
# ['AKU', 'KUAT', 'AKU', 'HEBAT', 'AKU', 'SEMANGATTTT']

# %%
from math import sqrt
from math import pi

#operasi hitungan sederhana
a = 25
b = 25
c = 2.5
d = 25/5

print(a+b)
print("bentuk bilangan integer = ", int(b))
print("bentuk bilangan float = ", float(a))
print("perkalian c x d = ", c*d)
print("-----------------------")
print("contoh soal")
print("Tentukan kecepatan (v) dengan usaha (w) = 35; jarak (s) = 25; waktu(t) = 5)")
w = 35
s = 25
t = 5
# Out:
# 50
# bentuk bilangan integer =  25
# bentuk bilangan float =  25.0
# perkalian c x d =  12.5
# -----------------------
# contoh soal
# Tentukan kecepatan (v) dengan usaha (w) = 35; jarak (s) = 25; waktu(t) = 5)

# %%
#v = s/t
kecepatan = s/t
print(kecepatan, "m/s")
# Out:
# 5.0 m/s

# %%
print("-----------------------")
print("soal 1")
print("Tentukan energi dalam J dari m = 9.31x10^-31; c = 3*10^8")
m = 9.31*10**-31
c = 3*10**8
# Out:
# -----------------------
# soal 1
# Tentukan energi dalam J dari m = 9.31x10^-31; c = 3*10^8

# %%
#energi
E = m * c**2
print(E)
# Out:
# 8.379e-14

# %%
print("-----------------------")
print("soal 2")
print("Tentukan periode dalam s (l = 20 m ; g = 9.8 m/s^2)")
l = 20
g = 9.8
# Out:
# -----------------------
# soal 2
# Tentukan periode dalam s (l = 20 m ; g = 9.8 m/s^2)

# %%
#periode = 2 x pi x sqrt (l/g)
periode = 2 * pi * sqrt (l/g)
print (periode)
# Out:
# 8.975979010256552

# %%
from numpy import *
#menampilkan matriks
M = [[0 , 1 , 1 , 0]] , [[2,3,2,1]]
print(M)
# Out:
# ([[0, 1, 1, 0]], [[2, 3, 2, 1]])

# %%
a = zeros ((3,3), int)
a[1,1] = 4
a[2,0:2] = [4,4]
print (a)
# Out:
# [[0 0 0]
#  [0 4 0]
#  [4 4 0]]

# %%
from numpy import array
print(' ')
A = array([[2,3,4],[2,3,6]])
print (A)
# Out:
#
# [[2 3 4]
#  [2 3 6]]

# %%
import matplotlib.pyplot as plt
from numpy import arange,sin,cos

x = arange(0.0,6.0,0.1)
plt.plot(x,sin(x),'o-',x,cos(x),'x-')
plt.title('GRAFIK SINUSOIDAL')
plt.xlabel('x')
plt.ylabel('y')
plt.legend('sinus','cosinus',loc = 0)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: Legend does not support 's' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: Legend does not support 'i' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: Legend does not support 'n' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: Legend does not support 'u' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   if __name__ == '__main__':

# %% [markdown]
# # Bagian 2 : Mengerjakan Soal Fisika

# %% [markdown]
# # Soal 1 : Optika

# %% [markdown]
# ![WhatsApp Image 2022-09-28 at 19.31.34.jpeg](data:image/jpeg;base64,...)

# %%
n = 1.50 #indeks bias medium 1

R1 = 20 #cm
R2 = 18 #cm

F = (n-1)*((1/R1)+(1/R2))
F = 1/F
print("Jarak Fokus Lensa = ",F,"cm")
# Out:
# Jarak Fokus Lensa =  18.94736842105263 cm

# %% [markdown]
# # Soal 2

# %% [markdown]
# ![WhatsApp Image 2022-09-28 at 19.31.33.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Posisi** \\
# $y=y_0+v_{0y}t-\dfrac{1}{2}gt^2$
#
# $x=x_0+v_{0x}t $ \\
# \
# \
# **Kecepatan** \\
# $v_{0x} = v_0 \cos t$ \\
# $v_x = v_{0x} = v_0 \cos t$ \\
# \
# $v_{0y} = v_0 \sin t$ \\
# $v_y = v_{0y}-gt = v_0 \sin t - gt $
#
# $v^2 = v_x^2 + v_y^2$
# \
# \
# Tinggi Maksimum\
# $H = \dfrac{v_0^2 \sin^2 \alpha }{2g}$ \\
#
# Jarak Maksimum\
# $X =\dfrac{v_0^2 \sin 2\alpha }{2g} $ \\
#
# Waktu Mencapai Jarak Maksimum\
# $T = \dfrac{2 v_0 \sin \alpha }{g}$

# %%
import numpy as np
import matplotlib.pyplot as plt

alpha = np.radians(45)
g = 9.8
v0 = 10

v0x = v0*np.cos(alpha)
v0y = v0*np.sin(alpha)

X = ((v0**2)*np.sin(2*alpha))/(2*g)
print("Jarak Horizontal Maksimum = ",X," m")
Y = ((v0**2)*(np.sin(alpha)**2))/(2*g)
print("Jarak Vertikal Maksimum = ",Y," m")
T = (2*v0*np.sin(alpha))/g
print("Waktu Mencapai Jarak Horizontal Maksimum = ",T," s")
print("\n")

t = np.arange(0.0, T, 0.01)
y = v0y*t - 0.5*g*t**2
x = v0x*t

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set(xlabel='x (m)', ylabel= 'y (m)', title='Grafik Gerak Parabola')
ax.grid()
plt.show()
# Out:
# Jarak Horizontal Maksimum =  5.1020408163265305  m
# Jarak Vertikal Maksimum =  2.5510204081632644  m
# Waktu Mencapai Jarak Horizontal Maksimum =  1.4430750636460152  s
